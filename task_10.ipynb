# %%
import pandas as pd

# %%
df=pd.read_csv("neet_data.csv")

# %%
df
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
dff= pd.DataFrame(df)

# %%
dff
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
df_sort=dff.sort_values("retweet_count",ascending=False)

# %%
df_sort.head()
# Out:
#                 created_at  retweet_count               source  \
# 32860  2020-11-08 05:30:01         614304   Twitter for iPhone
# 33262  2020-11-07 21:52:54         581097  Twitter for Android
# 35111  2020-11-06 14:20:33         381458      Twitter Web App
# 32585  2020-11-08 07:19:02         204348   Twitter for iPhone
# 38044  2020-11-04 18:19:13         192350   Twitter for iPhone
#
#                    user_id                                          user_name  \
# 32860  1024658968394625024               \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
# 33262  1099388669448867842                           Neet\xf0\x9f\x83\x8fPeet
# 35111           2578241503  \xe3\x81\xaf\xe3\x81\xaa\xe3\x81\x91\xe3\x81\x...
# 32585  1103362192169189376                                       Parneet kaur
# 38044             54249914                                       Couture_Neet
#
#                                         user_description  user_follower_count  \
# ...

# %%
df_sort.value_counts()
# Out:
# created_at           retweet_count  source               user_id              user_name             user_description                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    user_follower_count  user_friends_count  user_location              user_verified  user_url                 tweet                                                                                                                                                                                                                 length_of_tweet
# ...

# %%
highest_retweet = df_sort.iloc[0]
df_sort[["source", "retweet_count", "user_name", 
                 "tweet", "created_at", "user_url"]].head(1)
# Out:
#                    source  retweet_count  \
# 32860  Twitter for iPhone         614304
#
#                                   user_name  \
# 32860  \xe3\x81\xb2\xe3\x81\x88\xe3\x81\xa3
#
#                                                    tweet           created_at  \
# 32860  RT @JoeBiden: America, I\xe2\x80\x99m honored ...  2020-11-08 05:30:01
#
#                       user_url
# 32860  https://t.co/cHZdP4uOdu

# %%
top10= df_sort.head(10)
top10_sum=top10["retweet_count"].sum()
(f"TOP 10 Retweet sum is {top10_sum}")
# Out:
# 'TOP 10 Retweet sum is 2652225'

# %%
android = dff[dff["source"] == "Twitter for Android"]

print("Total Tweets from Twitter for Android:", android.shape[0])
print("Total Retweet Sum from Twitter for Android:", android["retweet_count"].sum())
# Out:
# Total Tweets from Twitter for Android: 28850
# Total Retweet Sum from Twitter for Android: 9386742

# %%
highest_followers=dff.loc[dff["user_follower_count"].idxmax()]

# %%
highest_followers
# Out:
# created_at                                           2020-11-01 10:49:41
# retweet_count                                                         15
# source                                    Twitter Media Studio - LiveCut
# user_id                                                         37034483
# user_name                                                           NDTV
# user_description       Breaking news alerts from India.\n\nInstagram:...
# user_follower_count                                             13934355
# user_friends_count                                                    15
# user_location                                                      India
# user_verified                                                       True
# user_url                                         https://t.co/6yvEvvCmQi
# tweet                  #Watch | Farmer's son Anil Kumar secures 77th ...
# length_of_tweet                                                      123
# ...

# %%
print("Username:", highest_followers["user_name"])
print("Location:", highest_followers["user_location"])
# Out:
# Username: NDTV
# Location: India

# %%
dff["followers_friend_ratio"] = dff["user_follower_count"] / dff["user_friends_count"]

# %%
dff
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
dff.isnull().sum()
# Out:
# created_at                    0
# retweet_count                 0
# source                       19
# user_id                       0
# user_name                     1
# user_description          10871
# user_follower_count           0
# user_friends_count            0
# user_location             21134
# user_verified                 0
# user_url                  38101
# tweet                         0
# length_of_tweet               0
# followers_friend_ratio      147
# dtype: int64

# %%
dff["user_description"].fillna("Twitter user", inplace=True)
# Out:
# /var/folders/7j/4mfq49jx199954g_vfv6fq_80000gn/T/ipykernel_27545/4020908461.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dff["user_description"].fillna("Twitter user", inplace=True)

# %%
dff
# Out:
#                 created_at  retweet_count               source  \
# 0      2020-10-31 14:10:28            141  Twitter for Android
# 1      2020-10-31 14:10:11              1   Twitter for iPhone
# 2      2020-10-31 14:09:48            141      Twitter Web App
# 3      2020-10-31 14:09:41            141  Twitter for Android
# 4      2020-10-31 14:09:22              0  Twitter for Android
# ...                    ...            ...                  ...
# 47376  2020-10-30 15:29:35              0  Twitter for Android
# 47377  2020-10-30 15:29:35           1700  Twitter for Android
# 47378  2020-10-30 15:28:59            167  Twitter for Android
# 47379  2020-10-30 15:28:37            270  Twitter for Android
# 47380  2020-10-30 15:28:14              0  Twitter for Android
#
#                    user_id               user_name  \
# 0      1250294694937915394                    Rumi
# 1                 57059492              Tom Bewick
# 2               1016022678                Lemonade
# ...

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47381 entries, 0 to 47380
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   created_at              47381 non-null  object
#  1   retweet_count           47381 non-null  int64
#  2   source                  47362 non-null  object
#  3   user_id                 47381 non-null  int64
#  4   user_name               47380 non-null  object
#  5   user_description        47381 non-null  object
#  6   user_follower_count     47381 non-null  int64
#  7   user_friends_count      47381 non-null  int64
#  8   user_location           26247 non-null  object
#  9   user_verified           47381 non-null  bool
#  10  user_url                9280 non-null   object
#  11  tweet                   47381 non-null  object
#  12  length_of_tweet         47381 non-null  int64
#  13  followers_friend_ratio  47234 non-null  float64
# ...

# %%
dff.dropna(axis=1, inplace=True)

# %%
dff.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47381 entries, 0 to 47380
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   created_at           47381 non-null  object
#  1   retweet_count        47381 non-null  int64
#  2   user_id              47381 non-null  int64
#  3   user_description     47381 non-null  object
#  4   user_follower_count  47381 non-null  int64
#  5   user_friends_count   47381 non-null  int64
#  6   user_verified        47381 non-null  bool
#  7   tweet                47381 non-null  object
#  8   length_of_tweet      47381 non-null  int64
# dtypes: bool(1), int64(5), object(3)
# memory usage: 2.9+ MB

# %%
dff.insert(2, "is_allow", True)

# %%
dff
# Out:
#                 created_at  retweet_count  is_allow              user_id  \
# 0      2020-10-31 14:10:28            141      True  1250294694937915394
# 1      2020-10-31 14:10:11              1      True             57059492
# 2      2020-10-31 14:09:48            141      True           1016022678
# 3      2020-10-31 14:09:41            141      True  1085818329816883201
# 4      2020-10-31 14:09:22              0      True  1227501071490113537
# ...                    ...            ...       ...                  ...
# 47376  2020-10-30 15:29:35              0      True  1168840190426632192
# 47377  2020-10-30 15:29:35           1700      True           1696615807
# 47378  2020-10-30 15:28:59            167      True  1313330869113745413
# 47379  2020-10-30 15:28:37            270      True  1161551282995388416
# 47380  2020-10-30 15:28:14              0      True  1211810532006612992
#
#                                         user_description  user_follower_count  \
# ...

# %%
dff.drop("tweet", axis=1, inplace=True)
dff.head()
# Out:
#             created_at  retweet_count  is_allow              user_id  \
# 0  2020-10-31 14:10:28            141      True  1250294694937915394
# 1  2020-10-31 14:10:11              1      True             57059492
# 2  2020-10-31 14:09:48            141      True           1016022678
# 3  2020-10-31 14:09:41            141      True  1085818329816883201
# 4  2020-10-31 14:09:22              0      True  1227501071490113537
#
#                                     user_description  user_follower_count  \
# 0                                       Twitter user                   14
# 1  Proud dad of three & cat, @SussexCCC fan. CEO ...                 2314
# 2  Wisdom is knowing the right path to take, Inte...                  285
# 3                                       Twitter user                  147
# 4                 it's not my attitude it's my style                    2
#
#    user_friends_count  user_verified  length_of_tweet
# ...

# %%
dff["created_at"]= dff["created_at"].astype(str)
dff["month"] = dff["created_at"].str.split("-").str[1]
dff["year"] = dff["created_at"].str.split("-").str[0]
dff[["month", "year"]]
# Out:
#       month  year
# 0        10  2020
# 1        10  2020
# 2        10  2020
# 3        10  2020
# 4        10  2020
# ...     ...   ...
# 47376    10  2020
# 47377    10  2020
# 47378    10  2020
# 47379    10  2020
# 47380    10  2020
#
# [47381 rows x 2 columns]

# %%
dff.head()
# Out:
#             created_at  retweet_count  is_allow              user_id  \
# 0  2020-10-31 14:10:28            141      True  1250294694937915394
# 1  2020-10-31 14:10:11              1      True             57059492
# 2  2020-10-31 14:09:48            141      True           1016022678
# 3  2020-10-31 14:09:41            141      True  1085818329816883201
# 4  2020-10-31 14:09:22              0      True  1227501071490113537
#
#                                     user_description  user_follower_count  \
# 0                                       Twitter user                   14
# 1  Proud dad of three & cat, @SussexCCC fan. CEO ...                 2314
# 2  Wisdom is knowing the right path to take, Inte...                  285
# 3                                       Twitter user                  147
# 4                 it's not my attitude it's my style                    2
#
#    user_friends_count  user_verified  length_of_tweet month  year
# ...
